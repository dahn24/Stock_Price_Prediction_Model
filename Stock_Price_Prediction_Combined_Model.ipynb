# %% [markdown]
# <a href="https://colab.research.google.com/github/dahn24/Stock_Price_Prediction_Model/blob/main/Stock_Price_Prediction_Combined_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
#Linear Regression Model

import yfinance as yf
import pandas as pd
import numpy as np


ticker = yf.Ticker('AAPL') #import data, loaded 5 years of past data of AAPL (Matrix form)
aapl_df = ticker.history(period="5y") #get data from 5 year period in dataframe
aapl_df.drop(['High','Low','Close','Volume'], axis=1, inplace=True) #only have two columns, not seven
data = np.empty(shape = (1259), dtype = float)
data=aapl_df[['Open']].to_numpy().flatten()


X = np.zeros((1250,3)) #Matrix of 1250 rows and 4 columns
Y = [0]*1250

for i in range(1250):
  X[i] = [data[1 + i], data[2 + i], data[3 + i]] #filling up matrix
  Y[i] = data[4 + i]


from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

# Create linear regression object
LR_regr = linear_model.LinearRegression()

# Train the model using the training sets
LR_regr.fit(X_train, y_train)

# Make predictions using the testing set
LR_y_pred = LR_regr.predict(X_test)

# The coefficients
print("Coefficients: \n", LR_regr.coef_)
# The mean squared error
LR_MSE = mean_squared_error(y_test, LR_y_pred)
print("Mean squared error: %.2f" % LR_MSE)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, LR_y_pred))
# Out:
# Coefficients:
#  [-0.06553909  0.10025964  0.96278859]
# Mean squared error: 8.58
# Coefficient of determination: 0.99

# %%
#NN(Scikit Learn Example)

from sklearn.neural_network import MLPRegressor


NN_regr = MLPRegressor(hidden_layer_sizes=(100, 50), random_state=1, max_iter=500).fit(X_train, y_train)
NN_y_pred_bef= NN_regr.predict(X_test) #NN_y_pred = list of all the predictions
NN_y_pred = NN_y_pred_bef.reshape(-1,1)
NN_MSE = mean_squared_error(y_test, NN_y_pred)
print("Mean squared error: %.2f" % NN_MSE)
# Out:
# Mean squared error: 9.47

# %%
#Decision Tree

from sklearn.tree import DecisionTreeRegressor

DT_regr = DecisionTreeRegressor(random_state=1).fit(X_train, y_train)
DT_y_pred_bef = DT_regr.predict(X_test)
DT_y_pred = DT_y_pred_bef.reshape(-1,1)
DT_MSE = mean_squared_error(y_test, DT_y_pred)
print("Mean squared error: %.2f" % DT_MSE)
# Out:
# Mean squared error: 21.56

# %%
X_test[0] = [179.3, 174.67, 174.61]
LR_pred_val = LR_regr.predict(X_test)[0]
print(LR_pred_val)
# Out:
# 174.3831278451888

# %%
X_test[0] = [179.3, 174.67, 174.61]
NN_pred_val = NN_regr.predict(X_test)[0]
print(NN_pred_val)
# Out:
# 173.5391741424397

# %%
X_test[0] = [179.3, 174.67, 174.61]
DT_pred_val =DT_regr.predict(X_test)[0]
print(DT_pred_val)
# Out:
# 179.051009669682

# %%
NN_err = 0
LR_err = 0
DT_err = 0
fin_err = 0
results_list = []

for i in range(len(LR_y_pred)):
  print("NN Predictions:" , NN_y_pred[i])
  print("LR Predictions:" , LR_y_pred[i])
  print("DT Predictions:" , DT_y_pred[i])
  print("Actual:",  y_test[i])
  LR_err += abs((y_test[i]- LR_y_pred[i]))
  NN_err += abs((y_test[i]- NN_y_pred[i]))
  DT_err += abs((y_test[i]- DT_y_pred[i]))
  LR_ratio = NN_err/(NN_err + LR_err + DT_err)
  NN_ratio = LR_err/(NN_err + LR_err + DT_err)
  DT_ratio = DT_err/(NN_err + LR_err + DT_err)
  print("Error ratio is" , LR_ratio, "(LR) :", NN_ratio, "(NN) :" , DT_ratio, "(DT)")
  final_pred = LR_ratio * LR_y_pred[i] + NN_ratio * NN_y_pred[i] + DT_ratio * DT_y_pred[i]
  results_list.append(final_pred)
  print("Final prediction value:" , final_pred)
  fin_err += abs((y_test[i]-final_pred)/y_test[i])
  print("")


print("Final Average Error is: " , (fin_err/len(LR_y_pred)) * 100, "%")
three_list = np.array(results_list)

three_MSE = mean_squared_error(y_test, three_list)
print("MSE value of Three Models Combination Model is: ", three_MSE)
# Out:
# NN Predictions: [179.21273952]
# LR Predictions: 179.72935280631245
# DT Predictions: [184.52771753]
# Actual: 181.20870480571682
# Error ratio is [0.29376926] (LR) : [0.21773332] (NN) : [0.48849743] (DT)
# Final prediction value: [181.9608577]
#
# NN Predictions: [237.41197661]
# LR Predictions: 237.60227482939803
# DT Predictions: [240.]
# Actual: 238.97000122070312
# Error ratio is [0.33060126] (LR) : [0.26484254] (NN) : [0.40455621] (DT)
# Final prediction value: [238.52189037]
#
# NN Predictions: [124.70814188]
# LR Predictions: 125.2238299498249
# DT Predictions: [125.36200611]
# Actual: 125.46319795799657
# Error ratio is [0.3637647] (LR) : [0.26055425] (NN) : [0.37568105] (DT)
# Final prediction value: [125.14137539]
#
# NN Predictions: [117.69398659]
# LR Predictions: 118.75342279450508
# DT Predictions: [122.66459306]
# Actual: 119.58090377809478
# Error ratio is [0.35116976] (LR) : [0.22183039] (NN) : [0.42699984] (DT)
# Final prediction value: [120.18847673]
#
# NN Predictions: [221.73941121]
# LR Predictions: 222.52988145487654
# DT Predictions: [217.66386764]
# Actual: 215.53686848493908
# Error ratio is [0.37609594] (LR) : [0.33085083] (NN) : [0.29305323] (DT)
# Final prediction value: [220.84235266]
#
# NN Predictions: [213.14722905]
# LR Predictions: 213.10403982258424
# DT Predictions: [213.69691814]
# Actual: 212.13601299934342
# Error ratio is [0.36732437] (LR) : [0.32528376] (NN) : [0.30739187] (DT)
# Final prediction value: [213.30033455]
#
# NN Predictions: [142.78506752]
# LR Predictions: 143.2577009444578
# DT Predictions: [140.71545633]
# Actual: 143.36095456781464
# Error ratio is [0.35112262] (LR) : [0.30072514] (NN) : [0.34815223] (DT)
# Final prediction value: [142.23048004]
#
# NN Predictions: [113.37325069]
# LR Predictions: 113.5275629195184
# DT Predictions: [112.13491305]
# Actual: 110.89956637288807
# Error ratio is [0.35650751] (LR) : [0.31636998] (NN) : [0.32712251] (DT)
# Final prediction value: [113.02317604]
#
# NN Predictions: [231.49073458]
# LR Predictions: 231.708209621134
# DT Predictions: [229.97999573]
# Actual: 231.27999877929688
# Error ratio is [0.34651909] (LR) : [0.31251993] (NN) : [0.34096098] (DT)
# Final prediction value: [231.05099083]
#
# NN Predictions: [172.9807024]
# LR Predictions: 172.96687897393915
# DT Predictions: [174.46713907]
# Actual: 174.66913933099835
# Error ratio is [0.35509743] (LR) : [0.3237283] (NN) : [0.32117426] (DT)
# Final prediction value: [173.45319894]
#
# NN Predictions: [231.78306743]
# LR Predictions: 232.59225585982426
# DT Predictions: [229.00944133]
# Actual: 233.640604190904
# Error ratio is [0.34127412] (LR) : [0.30023605] (NN) : [0.35848984] (DT)
# Final prediction value: [231.06490572]
#
# NN Predictions: [164.17986333]
# LR Predictions: 165.05052278208697
# DT Predictions: [161.47195061]
# Actual: 167.92137775453384
# Error ratio is [0.33136883] (LR) : [0.28570234] (NN) : [0.38292883] (DT)
# Final prediction value: [163.43143489]
#
# NN Predictions: [160.79386101]
# LR Predictions: 161.67871753155356
# DT Predictions: [164.53391474]
# Actual: 161.37378407895594
# Error ratio is [0.32140782] (LR) : [0.27455892] (NN) : [0.40403325] (DT)
# Final prediction value: [162.58936689]
#
# NN Predictions: [147.39872322]
# LR Predictions: 148.11782228318572
# DT Predictions: [145.23080194]
# Actual: 150.6977495476136
# Error ratio is [0.31744344] (LR) : [0.26845567] (NN) : [0.41410089] (DT)
# Final prediction value: [146.72925837]
#
# NN Predictions: [138.99262378]
# LR Predictions: 138.84932796413202
# DT Predictions: [138.45729988]
# Actual: 139.53946698760842
# Error ratio is [0.31533969] (LR) : [0.26920616] (NN) : [0.41545415] (DT)
# Final prediction value: [138.72503439]
#
# NN Predictions: [156.94624054]
# LR Predictions: 157.7175161250491
# DT Predictions: [156.01095456]
# Actual: 160.50991215775952
# Error ratio is [0.31673416] (LR) : [0.26791884] (NN) : [0.415347] (DT)
# Final prediction value: [156.80206164]
#
# NN Predictions: [159.68441585]
# LR Predictions: 160.90776776389458
# DT Predictions: [155.62916923]
# Actual: 153.37255959944574
# Error ratio is [0.3270898] (LR) : [0.29545413] (NN) : [0.37745607] (DT)
# Final prediction value: [158.55388434]
#
# NN Predictions: [213.39725903]
# LR Predictions: 213.83988942451342
# DT Predictions: [211.65977882]
# Actual: 213.93719187335407
# Error ratio is [0.32364126] (LR) : [0.28908251] (NN) : [0.38727623] (DT)
# Final prediction value: [212.8676277]
#
# NN Predictions: [176.54051419]
# LR Predictions: 177.2239584528774
# DT Predictions: [178.32334515]
# Actual: 175.41183484094861
# Error ratio is [0.31755405] (LR) : [0.29003947] (NN) : [0.39240648] (DT)
# Final prediction value: [177.45713911]
#
# NN Predictions: [166.44116407]
# LR Predictions: 166.78681359628487
# DT Predictions: [167.59647195]
# Actual: 161.95293260639133
# Error ratio is [0.3156765] (LR) : [0.29354516] (NN) : [0.39077834] (DT)
# Final prediction value: [167.0017468]
#
# NN Predictions: [121.45869073]
# LR Predictions: 122.0169185620957
# DT Predictions: [124.94527907]
# Actual: 121.27962561409095
# Error ratio is [0.30695299] (LR) : [0.28936203] (NN) : [0.40368498] (DT)
# Final prediction value: [123.03752378]
#
# NN Predictions: [120.88111193]
# LR Predictions: 121.81687811337021
# DT Predictions: [124.94527907]
# Actual: 121.66921718039119
# Error ratio is [0.30357675] (LR) : [0.2821973] (NN) : [0.41422595] (DT)
# Final prediction value: [122.84867228]
#
# NN Predictions: [131.16355793]
# LR Predictions: 130.6225873854127
# DT Predictions: [130.1013641]
# Actual: 130.87934957569854
# Error ratio is [0.30280628] (LR) : [0.28143183] (NN) : [0.41576189] (DT)
# Final prediction value: [130.55812893]
#
# NN Predictions: [119.521929]
# LR Predictions: 119.93378883657776
# DT Predictions: [116.6533536]
# Actual: 117.49256160951855
# Error ratio is [0.30550625] (LR) : [0.2874968] (NN) : [0.40699695] (DT)
# Final prediction value: [118.48025331]
#
# NN Predictions: [119.85791352]
# LR Predictions: 119.89529561086168
# DT Predictions: [117.00466041]
# Actual: 120.7616815886335
# Error ratio is [0.30065119] (LR) : [0.28302628] (NN) : [0.41632253] (DT)
# Final prediction value: [118.68127894]
#
# NN Predictions: [187.99713677]
# LR Predictions: 188.46911908506817
# DT Predictions: [188.18675407]
# Actual: 188.61314558971708
# Error ratio is [0.30224364] (LR) : [0.28184863] (NN) : [0.41590773] (DT)
# Final prediction value: [188.21865372]
#
# NN Predictions: [146.62307539]
# LR Predictions: 147.1514727711235
# DT Predictions: [151.0161367]
# Actual: 146.04084921172387
# Error ratio is [0.29378854] (LR) : [0.27731316] (NN) : [0.4288983] (DT)
# Final prediction value: [148.662489]
#
# NN Predictions: [188.86557975]
# LR Predictions: 189.76396299955562
# DT Predictions: [191.15806202]
# Actual: 189.88238464889707
# Error ratio is [0.29558308] (LR) : [0.27411302] (NN) : [0.4303039] (DT)
# Final prediction value: [190.1175907]
#
# NN Predictions: [175.36504008]
# LR Predictions: 176.1673037293727
# DT Predictions: [178.32334515]
# Actual: 177.1448814654077
# Error ratio is [0.29908867] (LR) : [0.27353697] (NN) : [0.42737437] (DT)
# Final prediction value: [176.8692918]
#
# NN Predictions: [149.86366241]
# LR Predictions: 148.9835404055369
# DT Predictions: [146.98970509]
# Actual: 148.13127588452474
# Error ratio is [0.30252961] (LR) : [0.27260703] (NN) : [0.42486335] (DT)
# Final prediction value: [148.37636029]
#
# NN Predictions: [175.08443475]
# LR Predictions: 175.83382754457648
# DT Predictions: [179.03225924]
# Actual: 177.52118590379774
# Error ratio is [0.30648151] (LR) : [0.27342322] (NN) : [0.42009527] (DT)
# Final prediction value: [176.97257217]
#
# NN Predictions: [194.53635175]
# LR Predictions: 195.63763622795247
# DT Predictions: [194.45366986]
# Actual: 192.53005531977516
# Error ratio is [0.30569834] (LR) : [0.27957857] (NN) : [0.41472308] (DT)
# Final prediction value: [194.8387225]
#
# NN Predictions: [184.74237156]
# LR Predictions: 185.7716108420869
# DT Predictions: [187.97850078]
# Actual: 186.99345141756788
# Error ratio is [0.3102141] (LR) : [0.27945396] (NN) : [0.41033194] (DT)
# Final prediction value: [186.38954327]
#
# NN Predictions: [144.97640244]
# LR Predictions: 145.4645235125644
# DT Predictions: [142.58950015]
# Actual: 146.3076667825046
# Error ratio is [0.3077625] (LR) : [0.27548773] (NN) : [0.41674976] (DT)
# Final prediction value: [144.13188684]
#
# NN Predictions: [201.48994913]
# LR Predictions: 202.92372508522817
# DT Predictions: [199.14398127]
# Actual: 198.85432303920933
# Error ratio is [0.31006658] (LR) : [0.28570959] (NN) : [0.40422383] (DT)
# Final prediction value: [200.98621902]
#
# NN Predictions: [131.78711089]
# LR Predictions: 132.09568090802048
# DT Predictions: [129.16380466]
# Actual: 131.0667075414383
# Error ratio is [0.30813434] (LR) : [0.28564151] (NN) : [0.40622416] (DT)
# Final prediction value: [130.81654155]
#
# NN Predictions: [179.89587633]
# LR Predictions: 180.59099759857762
# DT Predictions: [179.74818072]
# Actual: 182.17179668082835
# Error ratio is [0.30968645] (LR) : [0.28467067] (NN) : [0.40564287] (DT)
# Final prediction value: [180.0512343]
#
# NN Predictions: [244.35311056]
# LR Predictions: 245.23105369115277
# DT Predictions: [229.17645245]
# Actual: 244.3319283268952
# Error ratio is [0.28864574] (LR) : [0.26906319] (NN) : [0.44229107] (DT)
# Final prediction value: [237.89402473]
#
# NN Predictions: [229.50803057]
# LR Predictions: 229.41233909840477
# DT Predictions: [219.94636493]
# Actual: 237.2100067138672
# Error ratio is [0.28210616] (LR) : [0.2652709] (NN) : [0.45262294] (DT)
# Final prediction value: [225.15320616]
#
# NN Predictions: [128.73932631]
# LR Predictions: 129.50219626365723
# DT Predictions: [128.96863269]
# Actual: 127.86666981780208
# Error ratio is [0.28157013] (LR) : [0.26776324] (NN) : [0.45066663] (DT)
# Final prediction value: [129.05746843]
#
# NN Predictions: [206.27671606]
# LR Predictions: 207.14431720665735
# DT Predictions: [210.06160888]
# Actual: 204.93741112479617
# Error ratio is [0.27764341] (LR) : [0.2673545] (NN) : [0.45500208] (DT)
# Final prediction value: [208.23973392]
#
# NN Predictions: [225.60650834]
# LR Predictions: 226.69256366298976
# DT Predictions: [223.46003607]
# Actual: 229.03408635152135
# Error ratio is [0.27859627] (LR) : [0.26498758] (NN) : [0.45641615] (DT)
# Final prediction value: [224.9293947]
#
# NN Predictions: [163.818059]
# LR Predictions: 164.67205914951748
# DT Predictions: [161.47195061]
# Actual: 162.6969833628771
# Error ratio is [0.27831687] (LR) : [0.26778874] (NN) : [0.45389439] (DT)
# Final prediction value: [162.99085621]
#
# NN Predictions: [142.25695445]
# LR Predictions: 143.13430548979102
# DT Predictions: [140.71545633]
# Actual: 142.53067920795002
# Error ratio is [0.27672604] (LR) : [0.26739605] (NN) : [0.4558779] (DT)
# Final prediction value: [141.7970054]
#
# NN Predictions: [115.67468877]
# LR Predictions: 115.86668505797421
# DT Predictions: [116.48902916]
# Actual: 114.57919924030725
# Error ratio is [0.27642126] (LR) : [0.26785635] (NN) : [0.4557224] (DT)
# Final prediction value: [116.09887378]
#
# NN Predictions: [227.53646126]
# LR Predictions: 228.51513109627325
# DT Predictions: [227.25325936]
# Actual: 230.82000732421875
# Error ratio is [0.27883078] (LR) : [0.26738461] (NN) : [0.4537846] (DT)
# Final prediction value: [227.68083188]
#
# NN Predictions: [144.03053224]
# LR Predictions: 144.4646049363407
# DT Predictions: [145.8671441]
# Actual: 144.54434106770898
# Error ratio is [0.27876548] (LR) : [0.26600831] (NN) : [0.4552262] (DT)
# Final prediction value: [144.98761057]
#
# NN Predictions: [225.82797165]
# LR Predictions: 226.68443824088527
# DT Predictions: [223.46003607]
# Actual: 224.61464290366072
# Error ratio is [0.27869096] (LR) : [0.26879785] (NN) : [0.45251119] (DT)
# Final prediction value: [224.99514381]
#
# NN Predictions: [164.5273123]
# LR Predictions: 165.7036533375918
# DT Predictions: [161.47195061]
# Actual: 165.81085035411152
# Error ratio is [0.27772571] (LR) : [0.26438257] (NN) : [0.45789172] (DT)
# Final prediction value: [163.45498764]
#
# NN Predictions: [178.32105966]
# LR Predictions: 178.2450835930053
# DT Predictions: [178.87400466]
# Actual: 176.4708803946138
# Error ratio is [0.2782587] (LR) : [0.26492902] (NN) : [0.45681228] (DT)
# Final prediction value: [178.55251073]
#
# NN Predictions: [188.82334904]
# LR Predictions: 189.7441349678297
# DT Predictions: [191.15806202]
# Actual: 191.21630577539946
# Error ratio is [0.28214897] (LR) : [0.26622281] (NN) : [0.45162822] (DT)
# Final prediction value: [190.13757011]
#
# NN Predictions: [187.94459238]
# LR Predictions: 188.6856675507828
# DT Predictions: [188.29581153]
# Actual: 188.38504622543272
# Error ratio is [0.28276386] (LR) : [0.26646012] (NN) : [0.45077603] (DT)
# Final prediction value: [188.31246282]
#
# NN Predictions: [120.46260191]
# LR Predictions: 121.30498572855278
# DT Predictions: [124.14779942]
# Actual: 121.34153047949344
# Error ratio is [0.28225228] (LR) : [0.26364289] (NN) : [0.45410484] (DT)
# Final prediction value: [122.37383267]
#
# NN Predictions: [167.46075346]
# LR Predictions: 168.09497377895568
# DT Predictions: [167.82482887]
# Actual: 167.3979472668269
# Error ratio is [0.28145237] (LR) : [0.26477201] (NN) : [0.45377561] (DT)
# Final prediction value: [167.80446482]
#
# NN Predictions: [145.25525341]
# LR Predictions: 145.81685565301808
# DT Predictions: [145.69094622]
# Actual: 140.7764886965952
# Error ratio is [0.28262645] (LR) : [0.26820843] (NN) : [0.44916512] (DT)
# Final prediction value: [145.60967507]
#
# NN Predictions: [146.23099218]
# LR Predictions: 146.80030025092557
# DT Predictions: [145.23080194]
# Actual: 144.12455951269104
# Error ratio is [0.28385295] (LR) : [0.27124941] (NN) : [0.44489765] (DT)
# Final prediction value: [145.94760967]
#
# NN Predictions: [203.16239434]
# LR Predictions: 204.07825344331027
# DT Predictions: [202.76987229]
# Actual: 200.3726011094186
# Error ratio is [0.28457179] (LR) : [0.27475067] (NN) : [0.44067754] (DT)
# Final prediction value: [203.25004635]
#
# NN Predictions: [217.70044783]
# LR Predictions: 218.8239487582632
# DT Predictions: [219.54820461]
# Actual: 220.36812707547224
# Error ratio is [0.28787184] (LR) : [0.27518246] (NN) : [0.4369457] (DT)
# Final prediction value: [218.83124149]
#
# NN Predictions: [219.01411749]
# LR Predictions: 220.11481970501862
# DT Predictions: [222.54426752]
# Actual: 222.91254804497814
# Error ratio is [0.29275938] (LR) : [0.27742004] (NN) : [0.42982058] (DT)
# Final prediction value: [220.85368952]
#
# NN Predictions: [145.27827955]
# LR Predictions: 145.4512017431599
# DT Predictions: [146.19021955]
# Actual: 144.37909428379132
# Error ratio is [0.29221917] (LR) : [0.27747918] (NN) : [0.43030164] (DT)
# Final prediction value: [145.72122001]
#
# NN Predictions: [127.92873121]
# LR Predictions: 128.73120521419375
# DT Predictions: [129.55289592]
# Actual: 128.0220218638134
# Error ratio is [0.29070091] (LR) : [0.27763842] (NN) : [0.43166067] (DT)
# Final prediction value: [128.86309917]
#
# NN Predictions: [165.83739223]
# LR Predictions: 166.14276272237575
# DT Predictions: [167.98060965]
# Actual: 163.40580023778472
# Error ratio is [0.28969231] (LR) : [0.27771852] (NN) : [0.43258917] (DT)
# Final prediction value: [166.85298837]
#
# NN Predictions: [140.99784385]
# LR Predictions: 141.5606734878494
# DT Predictions: [142.9440403]
# Actual: 143.56655947024234
# Error ratio is [0.29233307] (LR) : [0.27911583] (NN) : [0.4285511] (DT)
# Final prediction value: [141.9964222]
#
# NN Predictions: [222.58697297]
# LR Predictions: 223.1603060553966
# DT Predictions: [224.18665241]
# Actual: 224.2240421118748
# Error ratio is [0.29439707] (LR) : [0.27985464] (NN) : [0.42574829] (DT)
# Final prediction value: [223.43682134]
#
# NN Predictions: [151.06029313]
# LR Predictions: 151.79493691133683
# DT Predictions: [151.71159512]
# Actual: 153.67938632559895
# Error ratio is [0.29613079] (LR) : [0.28003292] (NN) : [0.42383629] (DT)
# Final prediction value: [151.55388919]
#
# NN Predictions: [185.70750985]
# LR Predictions: 185.58194208664483
# DT Predictions: [180.6307339]
# Actual: 182.44534401847454
# Error ratio is [0.29810675] (LR) : [0.28202471] (NN) : [0.41986854] (DT)
# Final prediction value: [183.53849874]
#
# NN Predictions: [167.18397074]
# LR Predictions: 167.8206840608251
# DT Predictions: [166.83196113]
# Actual: 168.62818685521674
# Error ratio is [0.2986668] (LR) : [0.28123682] (NN) : [0.42009639] (DT)
# Final prediction value: [167.2262579]
#
# NN Predictions: [158.05881667]
# LR Predictions: 160.17324111237772
# DT Predictions: [155.62916923]
# Actual: 161.0703866988541
# Error ratio is [0.29917222] (LR) : [0.27723971] (NN) : [0.42358807] (DT)
# Final prediction value: [157.66222404]
#
# NN Predictions: [147.94142673]
# LR Predictions: 149.26685664662392
# DT Predictions: [150.23347121]
# Actual: 149.31503194180715
# Error ratio is [0.30071776] (LR) : [0.27586135] (NN) : [0.42342089] (DT)
# Final prediction value: [149.31050656]
#
# NN Predictions: [235.14853653]
# LR Predictions: 236.28828902242975
# DT Predictions: [223.26351529]
# Actual: 238.96170621081686
# Error ratio is [0.29447634] (LR) : [0.26833522] (NN) : [0.43718844] (DT)
# Final prediction value: [230.2881728]
#
# NN Predictions: [169.89154862]
# LR Predictions: 169.59415669264848
# DT Predictions: [173.37186388]
# Actual: 169.84035496658896
# Error ratio is [0.29214546] (LR) : [0.26664339] (NN) : [0.44121115] (DT)
# Final prediction value: [171.34022081]
#
# NN Predictions: [170.37227579]
# LR Predictions: 171.09908998739525
# DT Predictions: [171.69402651]
# Actual: 170.34109754225454
# Error ratio is [0.29086368] (LR) : [0.26704609] (NN) : [0.44209022] (DT)
# Final prediction value: [171.16801272]
#
# NN Predictions: [173.39736949]
# LR Predictions: 174.59408419884858
# DT Predictions: [175.78764198]
# Actual: 174.76816076178545
# Error ratio is [0.29220334] (LR) : [0.26595123] (NN) : [0.44184542] (DT)
# Final prediction value: [174.80318449]
#
# NN Predictions: [190.93468191]
# LR Predictions: 191.76508278269463
# DT Predictions: [193.51434462]
# Actual: 189.45595434700246
# Error ratio is [0.29048726] (LR) : [0.26642014] (NN) : [0.4430926] (DT)
# Final prediction value: [192.31893225]
#
# NN Predictions: [224.91432546]
# LR Predictions: 225.98817133244225
# DT Predictions: [226.47999573]
# Actual: 227.25326410482543
# Error ratio is [0.29271704] (LR) : [0.26662672] (NN) : [0.44065624] (DT)
# Final prediction value: [225.91858082]
#
# NN Predictions: [140.31998235]
# LR Predictions: 140.86075957833953
# DT Predictions: [144.76915921]
# Actual: 147.4209143273598
# Error ratio is [0.2974157] (LR) : [0.27109272] (NN) : [0.43149158] (DT)
# Final prediction value: [142.40060036]
#
# NN Predictions: [133.71122431]
# LR Predictions: 133.94417419238476
# DT Predictions: [133.18424984]
# Actual: 135.44093330808735
# Error ratio is [0.29761337] (LR) : [0.27111333] (NN) : [0.4312733] (DT)
# Final prediction value: [133.55328329]
#
# NN Predictions: [122.54701833]
# LR Predictions: 123.4242536986702
# DT Predictions: [122.79146423]
# Actual: 123.75270614592999
# Error ratio is [0.29853392] (LR) : [0.27042131] (NN) : [0.43104477] (DT)
# Final prediction value: [122.91426997]
#
# NN Predictions: [170.51874523]
# LR Predictions: 171.06519086350283
# DT Predictions: [171.69402651]
# Actual: 170.87432663815136
# Error ratio is [0.29843031] (LR) : [0.27006725] (NN) : [0.43150244] (DT)
# Final prediction value: [171.18895791]
#
# NN Predictions: [118.91502146]
# LR Predictions: 119.34198541218653
# DT Predictions: [117.42428765]
# Actual: 121.18563492753421
# Error ratio is [0.2982747] (LR) : [0.26951419] (NN) : [0.43221111] (DT)
# Final prediction value: [118.39806229]
#
# NN Predictions: [162.01505548]
# LR Predictions: 161.86253606208388
# DT Predictions: [163.78458163]
# Actual: 165.07421541409994
# Error ratio is [0.29982159] (LR) : [0.27177284] (NN) : [0.42840557] (DT)
# Final prediction value: [162.72740172]
#
# NN Predictions: [202.30057997]
# LR Predictions: 202.51692244972708
# DT Predictions: [205.39689809]
# Actual: 197.72601327833053
# Error ratio is [0.29882816] (LR) : [0.27207254] (NN) : [0.4290993] (DT)
# Final prediction value: [203.69385712]
#
# NN Predictions: [147.42850449]
# LR Predictions: 148.24095357502193
# DT Predictions: [147.25650688]
# Actual: 145.28561258669828
# Error ratio is [0.29888412] (LR) : [0.27397001] (NN) : [0.42714587] (DT)
# Final prediction value: [147.59786455]
#
# NN Predictions: [224.03044127]
# LR Predictions: 225.6434338858584
# DT Predictions: [228.90468821]
# Actual: 226.61178991769694
# Error ratio is [0.30040318] (LR) : [0.27281975] (NN) : [0.42677707] (DT)
# Final prediction value: [226.59520619]
#
# NN Predictions: [140.64817389]
# LR Predictions: 142.7454148472592
# DT Predictions: [138.87778758]
# Actual: 146.54991405453222
# Error ratio is [0.30160439] (LR) : [0.27116813] (NN) : [0.42722748] (DT)
# Final prediction value: [140.52435328]
#
# NN Predictions: [148.00128299]
# LR Predictions: 148.60322238414204
# DT Predictions: [145.23080194]
# Actual: 148.9133997765836
# Error ratio is [0.30061278] (LR) : [0.26938521] (NN) : [0.43000201] (DT)
# Final prediction value: [146.99092124]
#
# NN Predictions: [181.32876192]
# LR Predictions: 181.69576312192055
# DT Predictions: [183.83067067]
# Actual: 181.25836496086742
# Error ratio is [0.29912519] (LR) : [0.26870301] (NN) : [0.43217181] (DT)
# Final prediction value: [182.51979565]
#
# NN Predictions: [226.22315747]
# LR Predictions: 227.31645951203126
# DT Predictions: [228.97432934]
# Actual: 223.88800321688734
# Error ratio is [0.29757159] (LR) : [0.26957858] (NN) : [0.43284983] (DT)
# Final prediction value: [227.73933737]
#
# NN Predictions: [208.11595255]
# LR Predictions: 208.21334863688597
# DT Predictions: [207.94042487]
# Actual: 210.63095505795985
# Error ratio is [0.29798699] (LR) : [0.27018941] (NN) : [0.4318236] (DT)
# Final prediction value: [208.06917832]
#
# NN Predictions: [155.28462536]
# LR Predictions: 154.0282791265554
# DT Predictions: [155.36901795]
# Actual: 152.3108102727315
# Error ratio is [0.29909216] (LR) : [0.26956352] (NN) : [0.43134432] (DT)
# Final prediction value: [154.94526432]
#
# NN Predictions: [228.24725252]
# LR Predictions: 228.42942721890276
# DT Predictions: [226.28684806]
# Actual: 231.07000732421875
# Error ratio is [0.29869664] (LR) : [0.26936485] (NN) : [0.43193851] (DT)
# Final prediction value: [227.4548933]
#
# NN Predictions: [143.87380807]
# LR Predictions: 145.8742863133704
# DT Predictions: [143.3286067]
# Actual: 143.9301165589326
# Error ratio is [0.29752287] (LR) : [0.27138917] (NN) : [0.43108796] (DT)
# Final prediction value: [144.23396636]
#
# NN Predictions: [121.38234171]
# LR Predictions: 121.687467262391
# DT Predictions: [119.62967201]
# Actual: 121.87590368031279
# Error ratio is [0.29691089] (LR) : [0.27040675] (NN) : [0.43268236] (DT)
# Final prediction value: [120.71458756]
#
# NN Predictions: [132.70227732]
# LR Predictions: 133.3278800124472
# DT Predictions: [134.50698074]
# Actual: 133.52779446900757
# Error ratio is [0.29728292] (LR) : [0.26985411] (NN) : [0.43286298] (DT)
# Final prediction value: [133.66944761]
#
# NN Predictions: [187.97973371]
# LR Predictions: 188.622090216565
# DT Predictions: [188.29581153]
# Actual: 192.8175368647406
# Error ratio is [0.29856029] (LR) : [0.27070382] (NN) : [0.4307359] (DT)
# Final prediction value: [188.30766191]
#
# NN Predictions: [173.37392185]
# LR Predictions: 173.74143574596604
# DT Predictions: [170.94559986]
# Actual: 169.25217604772806
# Error ratio is [0.30018596] (LR) : [0.27334752] (NN) : [0.42646652] (DT)
# Final prediction value: [172.44864634]
#
# NN Predictions: [121.06500388]
# LR Predictions: 122.18701509001043
# DT Predictions: [121.05445274]
# Actual: 117.69886347897865
# Error ratio is [0.30018763] (LR) : [0.27552424] (NN) : [0.42428813] (DT)
# Final prediction value: [121.39734104]
#
# NN Predictions: [187.07077104]
# LR Predictions: 187.97022317537466
# DT Predictions: [187.80000754]
# Actual: 188.65279989002153
# Error ratio is [0.30117079] (LR) : [0.27525596] (NN) : [0.42357325] (DT)
# Final prediction value: [187.65054482]
#
# NN Predictions: [174.93737506]
# LR Predictions: 174.93669430946625
# DT Predictions: [173.87691154]
# Actual: 172.31221179761187
# Error ratio is [0.30203342] (LR) : [0.27638348] (NN) : [0.4215831] (DT)
# Final prediction value: [174.49009595]
#
# NN Predictions: [150.7783462]
# LR Predictions: 151.38577066660136
# DT Predictions: [151.71159512]
# Actual: 151.60624021713144
# Error ratio is [0.30275409] (LR) : [0.27623557] (NN) : [0.42101035] (DT)
# Final prediction value: [151.35515389]
#
# NN Predictions: [128.55648089]
# LR Predictions: 129.46942408095757
# DT Predictions: [125.88221911]
# Actual: 129.24188600929259
# Error ratio is [0.30184578] (LR) : [0.27481262] (NN) : [0.4233416] (DT)
# Final prediction value: [127.69992268]
#
# NN Predictions: [223.27655796]
# LR Predictions: 223.2600198130488
# DT Predictions: [224.18665241]
# Actual: 222.70455320631825
# Error ratio is [0.30152489] (LR) : [0.27457208] (NN) : [0.42390303] (DT)
# Final prediction value: [223.65736309]
#
# NN Predictions: [142.71197779]
# LR Predictions: 143.23937410169935
# DT Predictions: [140.71545633]
# Actual: 145.8377859484882
# Error ratio is [0.30131303] (LR) : [0.27401608] (NN) : [0.42467089] (DT)
# Final prediction value: [142.02302462]
#
# NN Predictions: [132.48810968]
# LR Predictions: 133.3576487034433
# DT Predictions: [133.18424984]
# Actual: 136.19914460303502
# Error ratio is [0.30250895] (LR) : [0.27433355] (NN) : [0.4231575] (DT)
# Final prediction value: [133.04572995]
#
# NN Predictions: [167.99242231]
# LR Predictions: 168.86979939395138
# DT Predictions: [167.89196395]
# Actual: 170.09496475942944
# Error ratio is [0.30312414] (LR) : [0.27391513] (NN) : [0.42296073] (DT)
# Final prediction value: [168.21588654]
#
# NN Predictions: [114.50002422]
# LR Predictions: 114.77769854806293
# DT Predictions: [110.99344264]
# Actual: 115.60234248642783
# Error ratio is [0.30187686] (LR) : [0.27254471] (NN) : [0.42557842] (DT)
# Final prediction value: [113.09152222]
#
# NN Predictions: [140.58886283]
# LR Predictions: 141.32094335651058
# DT Predictions: [146.82923769]
# Actual: 141.13281900063922
# Error ratio is [0.29991265] (LR) : [0.27034526] (NN) : [0.42974209] (DT)
# Final prediction value: [143.49017479]
#
# NN Predictions: [107.82165004]
# LR Predictions: 108.1437726146676
# DT Predictions: [109.30429842]
# Actual: 106.1332257311281
# Error ratio is [0.29939451] (LR) : [0.27055874] (NN) : [0.43004676] (DT)
# Final prediction value: [108.55569989]
#
# NN Predictions: [141.15896382]
# LR Predictions: 141.06808253714314
# DT Predictions: [144.76915921]
# Actual: 141.96778362091698
# Error ratio is [0.29864507] (LR) : [0.27011511] (NN) : [0.43123982] (DT)
# Final prediction value: [142.68868259]
#
# NN Predictions: [140.17234007]
# LR Predictions: 140.90533063540704
# DT Predictions: [141.83117538]
# Actual: 140.4338327387145
# Error ratio is [0.2981279] (LR) : [0.26997166] (NN) : [0.43190044] (DT)
# Final prediction value: [141.10731671]
#
# NN Predictions: [239.03044968]
# LR Predictions: 239.93906422371097
# DT Predictions: [241.22999573]
# Actual: 239.3000030517578
# Error ratio is [0.29733506] (LR) : [0.26979668] (NN) : [0.43286826] (DT)
# Final prediction value: [240.25272631]
#
# NN Predictions: [122.04087531]
# LR Predictions: 122.43266598395238
# DT Predictions: [125.83611931]
# Actual: 121.4848886960278
# Error ratio is [0.2957191] (LR) : [0.26893493] (NN) : [0.43534596] (DT)
# Final prediction value: [123.80897945]
#
# NN Predictions: [128.06843309]
# LR Predictions: 128.14586735769518
# DT Predictions: [126.08008115]
# Actual: 126.2100445910704
# Error ratio is [0.29666587] (LR) : [0.27012932] (NN) : [0.43320482] (DT)
# Final prediction value: [127.23004155]
#
# NN Predictions: [227.72661339]
# LR Predictions: 227.76005678949994
# DT Predictions: [220.63318012]
# Actual: 235.11237576276483
# Error ratio is [0.2949931] (LR) : [0.26942456] (NN) : [0.43558234] (DT)
# Final prediction value: [224.64670467]
#
# NN Predictions: [179.72978006]
# LR Predictions: 180.3930434996183
# DT Predictions: [180.64276986]
# Actual: 180.56128223575337
# Error ratio is [0.29566093] (LR) : [0.2692642] (NN) : [0.43507487] (DT)
# Final prediction value: [180.32310006]
#
# NN Predictions: [140.5816136]
# LR Predictions: 141.1905540511723
# DT Predictions: [139.27865728]
# Actual: 142.80429232334566
# Error ratio is [0.29572031] (LR) : [0.26878849] (NN) : [0.4354912] (DT)
# Final prediction value: [140.19426364]
#
# NN Predictions: [245.73861031]
# LR Predictions: 247.1146211387786
# DT Predictions: [253.86880357]
# Actual: 243.7333937698084
# Error ratio is [0.29244977] (LR) : [0.26778785] (NN) : [0.43976238] (DT)
# Final prediction value: [249.71637747]
#
# NN Predictions: [171.63390008]
# LR Predictions: 173.04006416331555
# DT Predictions: [174.24322515]
# Actual: 175.34253031574917
# Error ratio is [0.29449272] (LR) : [0.26828742] (NN) : [0.43721987] (DT)
# Final prediction value: [173.18885393]
#
# NN Predictions: [171.48151316]
# LR Predictions: 170.88891578891966
# DT Predictions: [171.36699666]
# Actual: 169.3538487990515
# Error ratio is [0.29506068] (LR) : [0.26830273] (NN) : [0.43663659] (DT)
# Final prediction value: [171.25665888]
#
# NN Predictions: [138.09385729]
# LR Predictions: 139.22104526675628
# DT Predictions: [140.79745205]
# Actual: 143.79208769866335
# Error ratio is [0.29724655] (LR) : [0.26954267] (NN) : [0.43321079] (DT)
# Final prediction value: [139.60013644]
#
# NN Predictions: [139.68242872]
# LR Predictions: 139.31286131663703
# DT Predictions: [146.14883626]
# Actual: 136.0621976067289
# Error ratio is [0.29554222] (LR) : [0.2679586] (NN) : [0.43649918] (DT)
# Final prediction value: [142.39578755]
#
# NN Predictions: [131.79664017]
# LR Predictions: 132.91773740336433
# DT Predictions: [134.03328355]
# Actual: 134.91724588612811
# Error ratio is [0.29714597] (LR) : [0.26842402] (NN) : [0.43443001] (DT)
# Final prediction value: [133.1014347]
#
# NN Predictions: [239.63539569]
# LR Predictions: 240.7938843506625
# DT Predictions: [248.30000305]
# Actual: 243.55383619329416
# Error ratio is [0.29776148] (LR) : [0.26806357] (NN) : [0.43417495] (DT)
# Final prediction value: [243.74230445]
#
# NN Predictions: [132.8334497]
# LR Predictions: 132.6178367011149
# DT Predictions: [130.32547623]
# Actual: 133.39867443914102
# Error ratio is [0.29688374] (LR) : [0.2675914] (NN) : [0.43552486] (DT)
# Final prediction value: [131.67715292]
#
# NN Predictions: [163.83781799]
# LR Predictions: 164.34528166388654
# DT Predictions: [167.48948624]
# Actual: 164.17107024309314
# Error ratio is [0.29594946] (LR) : [0.26660244] (NN) : [0.4374481] (DT)
# Final prediction value: [165.58541692]
#
# NN Predictions: [174.77742072]
# LR Predictions: 175.52655740757785
# DT Predictions: [176.37245707]
# Actual: 176.78840288374346
# Error ratio is [0.29701502] (LR) : [0.26692515] (NN) : [0.43605983] (DT)
# Final prediction value: [175.69545685]
#
# NN Predictions: [188.4410407]
# LR Predictions: 188.6540626107264
# DT Predictions: [188.18675407]
# Actual: 188.2350632210391
# Error ratio is [0.29702197] (LR) : [0.26720228] (NN) : [0.43577575] (DT)
# Final prediction value: [188.39350094]
#
# NN Predictions: [173.53907368]
# LR Predictions: 174.58682373873802
# DT Predictions: [170.83692448]
# Actual: 177.44195927584823
# Error ratio is [0.29694642] (LR) : [0.26638622] (NN) : [0.43666736] (DT)
# Final prediction value: [172.67025896]
#
# NN Predictions: [173.46770799]
# LR Predictions: 172.47660141592777
# DT Predictions: [173.12426626]
# Actual: 171.67834915746462
# Error ratio is [0.2976181] (LR) : [0.26607261] (NN) : [0.43630928] (DT)
# Final prediction value: [173.02288992]
#
# NN Predictions: [170.32307512]
# LR Predictions: 171.64308108135697
# DT Predictions: [174.10968609]
# Actual: 171.91544162555573
# Error ratio is [0.29805246] (LR) : [0.2651599] (NN) : [0.43678764] (DT)
# Final prediction value: [172.37045101]
#
# NN Predictions: [135.95556542]
# LR Predictions: 136.56188224802517
# DT Predictions: [136.96793266]
# Actual: 140.05201606913297
# Error ratio is [0.29907535] (LR) : [0.26589768] (NN) : [0.43502697] (DT)
# Final prediction value: [136.5773069]
#
# NN Predictions: [166.60290596]
# LR Predictions: 166.8250834578967
# DT Predictions: [167.59647195]
# Actual: 163.7076835662155
# Error ratio is [0.2990024] (LR) : [0.26643293] (NN) : [0.43456466] (DT)
# Final prediction value: [167.10110624]
#
# NN Predictions: [235.53113583]
# LR Predictions: 236.05561311305038
# DT Predictions: [232.19000244]
# Actual: 241.19958958341564
# Error ratio is [0.29872315] (LR) : [0.26628458] (NN) : [0.43499226] (DT)
# Final prediction value: [234.23444217]
#
# NN Predictions: [117.71688006]
# LR Predictions: 118.17769640020381
# DT Predictions: [118.75143928]
# Actual: 116.1556711821871
# Error ratio is [0.2984176] (LR) : [0.26668896] (NN) : [0.43489344] (DT)
# Final prediction value: [118.30431878]
#
# NN Predictions: [150.6817928]
# LR Predictions: 152.05361830238505
# DT Predictions: [147.0560472]
# Actual: 151.79390348554702
# Error ratio is [0.2976591] (LR) : [0.26522805] (NN) : [0.43711285] (DT)
# Final prediction value: [149.50526917]
#
# NN Predictions: [142.23415349]
# LR Predictions: 140.75228812702434
# DT Predictions: [140.113932]
# Actual: 142.14562929103238
# Error ratio is [0.29664182] (LR) : [0.2657184] (NN) : [0.43763978] (DT)
# Final prediction value: [140.86667698]
#
# NN Predictions: [215.1788832]
# LR Predictions: 218.2831735068339
# DT Predictions: [219.54820461]
# Actual: 220.57966572513484
# Error ratio is [0.29960193] (LR) : [0.26569429] (NN) : [0.43470377] (DT)
# Final prediction value: [218.00829508]
#
# NN Predictions: [152.47250797]
# LR Predictions: 153.14216889285836
# DT Predictions: [156.32810562]
# Actual: 157.10995164172124
# Error ratio is [0.30150467] (LR) : [0.26723071] (NN) : [0.43126462] (DT)
# Final prediction value: [154.33719671]
#
# NN Predictions: [143.3765667]
# LR Predictions: 143.30931092339708
# DT Predictions: [145.85734044]
# Actual: 142.2833621487803
# Error ratio is [0.30085868] (LR) : [0.26671724] (NN) : [0.43242408] (DT)
# Final prediction value: [144.42907853]
#
# NN Predictions: [167.09244497]
# LR Predictions: 167.9483843504834
# DT Predictions: [164.29911353]
# Actual: 166.6684893743364
# Error ratio is [0.30003147] (LR) : [0.26691694] (NN) : [0.43305159] (DT)
# Final prediction value: [166.13959711]
#
# NN Predictions: [189.70840937]
# LR Predictions: 189.70870483321548
# DT Predictions: [183.47271805]
# Actual: 187.74502176003202
# Error ratio is [0.29952317] (LR) : [0.26668681] (NN) : [0.43379002] (DT)
# Final prediction value: [187.0035172]
#
# NN Predictions: [227.26393757]
# LR Predictions: 227.7028480999398
# DT Predictions: [230.63545744]
# Actual: 232.527799450427
# Error ratio is [0.30121683] (LR) : [0.26833447] (NN) : [0.43044871] (DT)
# Final prediction value: [228.84741117]
#
# NN Predictions: [227.46681246]
# LR Predictions: 228.35638346858588
# DT Predictions: [227.72160927]
# Actual: 232.23917058038825
# Error ratio is [0.3020195] (LR) : [0.26868177] (NN) : [0.42929873] (DT)
# Final prediction value: [227.8448642]
#
# NN Predictions: [158.94860991]
# LR Predictions: 159.41562535282083
# DT Predictions: [153.04937169]
# Actual: 160.33664331436313
# Error ratio is [0.300527] (LR) : [0.2670439] (NN) : [0.43242909] (DT)
# Final prediction value: [156.53795843]
#
# NN Predictions: [193.0257885]
# LR Predictions: 192.81870824369574
# DT Predictions: [195.64111763]
# Actual: 206.1707358379729
# Error ratio is [0.30245038] (LR) : [0.27034664] (NN) : [0.42720298] (DT)
# Final prediction value: [194.0804334]
#
# NN Predictions: [171.7305696]
# LR Predictions: 173.26140806784494
# DT Predictions: [172.06006024]
# Actual: 175.27397290735905
# Error ratio is [0.30329273] (LR) : [0.27000785] (NN) : [0.42669942] (DT)
# Final prediction value: [172.33545525]
#
# NN Predictions: [137.93018061]
# LR Predictions: 138.6320405517678
# DT Predictions: [140.31169407]
# Actual: 138.93063463423644
# Error ratio is [0.30346965] (LR) : [0.26960699] (NN) : [0.42692336] (DT)
# Final prediction value: [139.15989753]
#
# NN Predictions: [139.39226187]
# LR Predictions: 140.21877192223272
# DT Predictions: [142.25694855]
# Actual: 140.36048819280174
# Error ratio is [0.30352219] (LR) : [0.26897802] (NN) : [0.42749979] (DT)
# Final prediction value: [140.86777897]
#
# NN Predictions: [252.78551822]
# LR Predictions: 253.81386387366518
# DT Predictions: [255.03999329]
# Actual: 254.55999755859375
# Error ratio is [0.30433216] (LR) : [0.26892085] (NN) : [0.42674699] (DT)
# Final prediction value: [254.06056733]
#
# NN Predictions: [227.05034846]
# LR Predictions: 227.922912249254
# DT Predictions: [227.25325936]
# Actual: 230.0518062316796
# Error ratio is [0.3048799] (LR) : [0.26891773] (NN) : [0.42620237] (DT)
# Final prediction value: [227.40285673]
#
# NN Predictions: [145.12518209]
# LR Predictions: 145.43553659791894
# DT Predictions: [149.45018454]
# Actual: 145.00908849876785
# Error ratio is [0.30357967] (LR) : [0.26807111] (NN) : [0.42834921] (DT)
# Final prediction value: [147.07201081]
#
# NN Predictions: [153.64147668]
# LR Predictions: 154.7249530380096
# DT Predictions: [158.51411543]
# Actual: 158.5115259485219
# Error ratio is [0.30563979] (LR) : [0.26941795] (NN) : [0.42494226] (DT)
# Final prediction value: [156.0432203]
#
# NN Predictions: [151.28325909]
# LR Predictions: 151.7883949910081
# DT Predictions: [148.34720183]
# Actual: 150.46064065840176
# Error ratio is [0.30519979] (LR) : [0.26958185] (NN) : [0.42521837] (DT)
# Final prediction value: [150.18896098]
#
# NN Predictions: [153.22894355]
# LR Predictions: 152.70906304430335
# DT Predictions: [152.89082298]
# Actual: 152.24671887947383
# Error ratio is [0.30551484] (LR) : [0.2694898] (NN) : [0.42499536] (DT)
# Final prediction value: [152.92641267]
#
# NN Predictions: [197.23089914]
# LR Predictions: 198.34523777951588
# DT Predictions: [197.07634287]
# Actual: 197.2372161152265
# Error ratio is [0.305165] (LR) : [0.27018749] (NN) : [0.42464752] (DT)
# Final prediction value: [197.50532435]
#
# NN Predictions: [145.74765462]
# LR Predictions: 147.26616705901574
# DT Predictions: [144.59351795]
# Actual: 148.19163331287257
# Error ratio is [0.30545317] (LR) : [0.26931942] (NN) : [0.42522741] (DT)
# Final prediction value: [145.7207185]
#
# NN Predictions: [229.49855577]
# LR Predictions: 229.93417801907108
# DT Predictions: [233.97938842]
# Actual: 226.27000427246094
# Error ratio is [0.30435062] (LR) : [0.26907911] (NN) : [0.42657027] (DT)
# Final prediction value: [231.54252768]
#
# NN Predictions: [142.77815242]
# LR Predictions: 143.16109278880705
# DT Predictions: [140.71545633]
# Actual: 143.11621825238865
# Error ratio is [0.30389598] (LR) : [0.26845035] (NN) : [0.42765366] (DT)
# Final prediction value: [142.01240692]
#
# NN Predictions: [206.63238939]
# LR Predictions: 207.7085529578905
# DT Predictions: [208.56948084]
# Actual: 210.2768443064002
# Error ratio is [0.30499326] (LR) : [0.26884237] (NN) : [0.42616437] (DT)
# Final prediction value: [207.78613138]
#
# NN Predictions: [171.04448317]
# LR Predictions: 171.74538002383176
# DT Predictions: [169.94956267]
# Actual: 171.70403494878815
# Error ratio is [0.30491424] (LR) : [0.26829494] (NN) : [0.42679082] (DT)
# Final prediction value: [170.79089458]
#
# NN Predictions: [128.938536]
# LR Predictions: 128.4875660433608
# DT Predictions: [126.08008115]
# Actual: 126.08008757945029
# Error ratio is [0.30601747] (LR) : [0.26917085] (NN) : [0.42481168] (DT)
# Final prediction value: [127.58622631]
#
# NN Predictions: [169.39204037]
# LR Predictions: 169.6255517780901
# DT Predictions: [170.58909601]
# Actual: 172.10426293848624
# Error ratio is [0.3065953] (LR) : [0.26976057] (NN) : [0.42364413] (DT)
# Final prediction value: [169.97075947]
#
# NN Predictions: [162.50506595]
# LR Predictions: 161.97731065698576
# DT Predictions: [160.41564039]
# Actual: 160.3626871229987
# Error ratio is [0.30744538] (LR) : [0.27027262] (NN) : [0.422282] (DT)
# Final prediction value: [161.46048321]
#
# NN Predictions: [154.35504331]
# LR Predictions: 155.92640116230103
# DT Predictions: [148.67120307]
# Actual: 158.87057095053723
# Error ratio is [0.30666027] (LR) : [0.26870132] (NN) : [0.42463842] (DT)
# Final prediction value: [152.42333939]
#
# NN Predictions: [225.68344537]
# LR Predictions: 226.40796790370544
# DT Predictions: [223.46003607]
# Actual: 226.8699951171875
# Error ratio is [0.30634824] (LR) : [0.26793368] (NN) : [0.42571808] (DT)
# Final prediction value: [224.95885603]
#
# NN Predictions: [177.42013099]
# LR Predictions: 178.33077858427725
# DT Predictions: [177.95693577]
# Actual: 179.6602366589199
# Error ratio is [0.30688038] (LR) : [0.26786272] (NN) : [0.42525691] (DT)
# Final prediction value: [177.92787081]
#
# NN Predictions: [111.12919901]
# LR Predictions: 111.14555409374306
# DT Predictions: [109.30429842]
# Actual: 112.33918213169002
# Error ratio is [0.30649125] (LR) : [0.26763962] (NN) : [0.42586913] (DT)
# Final prediction value: [110.35704287]
#
# NN Predictions: [200.84761274]
# LR Predictions: 200.6053588870026
# DT Predictions: [193.45045269]
# Actual: 203.26930749599725
# Error ratio is [0.30469422] (LR) : [0.26653023] (NN) : [0.42877556] (DT)
# Final prediction value: [197.60207796]
#
# NN Predictions: [141.74450843]
# LR Predictions: 142.26260553673825
# DT Predictions: [143.12599829]
# Actual: 139.43354266054223
# Error ratio is [0.3043782] (LR) : [0.26692494] (NN) : [0.42869686] (DT)
# Final prediction value: [142.49444626]
#
# NN Predictions: [157.72305977]
# LR Predictions: 158.76678821125262
# DT Predictions: [157.96248574]
# Actual: 158.28800912044616
# Error ratio is [0.30450121] (LR) : [0.26701899] (NN) : [0.4284798] (DT)
# Final prediction value: [158.14346554]
#
# NN Predictions: [221.9979425]
# LR Predictions: 223.07165033438372
# DT Predictions: [205.03811567]
# Actual: 217.88258518105536
# Error ratio is [0.30235818] (LR) : [0.26642791] (NN) : [0.43121391] (DT)
# Final prediction value: [215.00927363]
#
# NN Predictions: [172.1073421]
# LR Predictions: 172.40340135212378
# DT Predictions: [177.5705625]
# Actual: 168.37089789825708
# Error ratio is [0.30123724] (LR) : [0.26603522] (NN) : [0.43272754] (DT)
# Final prediction value: [174.56061211]
#
# NN Predictions: [113.8156715]
# LR Predictions: 113.12711790449005
# DT Predictions: [113.58534323]
# Actual: 114.18945127149735
# Error ratio is [0.30104394] (LR) : [0.26645228] (NN) : [0.43250379] (DT)
# Final prediction value: [113.50876877]
#
# NN Predictions: [124.79831941]
# LR Predictions: 125.46932808388003
# DT Predictions: [124.50831458]
# Actual: 130.3742269570898
# Error ratio is [0.30156277] (LR) : [0.26688748] (NN) : [0.43154975] (DT)
# Final prediction value: [124.87551913]
#
# NN Predictions: [208.98835913]
# LR Predictions: 210.3099473152407
# DT Predictions: [209.69201166]
# Actual: 204.27816503495924
# Error ratio is [0.30143619] (LR) : [0.26823303] (NN) : [0.43033078] (DT)
# Final prediction value: [209.68953698]
#
# NN Predictions: [141.96734972]
# LR Predictions: 143.03259908176284
# DT Predictions: [141.83117538]
# Actual: 140.79071085179643
# Error ratio is [0.30130564] (LR) : [0.26904835] (NN) : [0.42964601] (DT)
# Final prediction value: [142.2298086]
#
# NN Predictions: [181.30428799]
# LR Predictions: 184.86941826831284
# DT Predictions: [185.64558872]
# Actual: 171.53013119082922
# Error ratio is [0.30021234] (LR) : [0.27156577] (NN) : [0.42822189] (DT)
# Final prediction value: [184.23362409]
#
# NN Predictions: [213.44954325]
# LR Predictions: 213.07371843749615
# DT Predictions: [214.45660522]
# Actual: 209.17326157128963
# Error ratio is [0.30038887] (LR) : [0.27174963] (NN) : [0.4278615] (DT)
# Final prediction value: [213.7675327]
#
# NN Predictions: [131.51904562]
# LR Predictions: 132.17745059857953
# DT Predictions: [128.08060684]
# Actual: 129.8471144138601
# Error ratio is [0.30034337] (LR) : [0.27231913] (NN) : [0.4273375] (DT)
# Final prediction value: [130.24741934]
#
# NN Predictions: [172.03900951]
# LR Predictions: 172.28531421337902
# DT Predictions: [179.05100967]
# Actual: 174.76816613453047
# Error ratio is [0.30025249] (LR) : [0.27224292] (NN) : [0.42750458] (DT)
# Final prediction value: [175.11062531]
#
# NN Predictions: [132.92391262]
# LR Predictions: 132.63182115539436
# DT Predictions: [130.32547623]
# Actual: 130.64699691249126
# Error ratio is [0.30091812] (LR) : [0.27278758] (NN) : [0.4262943] (DT)
# Final prediction value: [131.72831839]
#
# NN Predictions: [124.31218476]
# LR Predictions: 124.51134816465512
# DT Predictions: [123.68428989]
# Actual: 128.65553802002677
# Error ratio is [0.30113277] (LR) : [0.27313351] (NN) : [0.42573372] (DT)
# Final prediction value: [124.10484337]
#
# NN Predictions: [171.49836927]
# LR Predictions: 172.48327519671633
# DT Predictions: [172.11414682]
# Actual: 173.61955533140323
# Error ratio is [0.30163363] (LR) : [0.27301348] (NN) : [0.42535289] (DT)
# Final prediction value: [172.05737278]
#
# NN Predictions: [151.08548871]
# LR Predictions: 151.14547520261831
# DT Predictions: [146.98970509]
# Actual: 140.3563740008872
# Error ratio is [0.30323236] (LR) : [0.27523072] (NN) : [0.42153692] (DT)
# Final prediction value: [149.37715452]
#
# NN Predictions: [240.8554002]
# LR Predictions: 241.97750212063798
# DT Predictions: [248.30000305]
# Actual: 243.12691898237586
# Error ratio is [0.30299485] (LR) : [0.27436728] (NN) : [0.42263786] (DT)
# Final prediction value: [244.34176235]
#
# NN Predictions: [233.30553315]
# LR Predictions: 233.96868657776346
# DT Predictions: [231.69999695]
# Actual: 236.4306920263062
# Error ratio is [0.30299408] (LR) : [0.27410725] (NN) : [0.42289867] (DT)
# Final prediction value: [232.82748558]
#
# NN Predictions: [165.46284907]
# LR Predictions: 165.4096628027886
# DT Predictions: [164.71984653]
# Actual: 167.38051344932887
# Error ratio is [0.30294727] (LR) : [0.27423052] (NN) : [0.42282221] (DT)
# Final prediction value: [165.13257846]
#
# NN Predictions: [170.31564119]
# LR Predictions: 170.47733592877805
# DT Predictions: [169.16808988]
# Actual: 168.71741923518283
# Error ratio is [0.30325825] (LR) : [0.27473119] (NN) : [0.42201056] (DT)
# Final prediction value: [169.88039768]
#
# NN Predictions: [188.29231016]
# LR Predictions: 189.3438998028113
# DT Predictions: [185.46976492]
# Actual: 188.4140082479681
# Error ratio is [0.30249751] (LR) : [0.27461403] (NN) : [0.42288846] (DT)
# Final prediction value: [187.41679159]
#
# NN Predictions: [118.14625357]
# LR Predictions: 117.77822095304113
# DT Predictions: [117.42428765]
# Actual: 119.29529488946088
# Error ratio is [0.30234208] (LR) : [0.27480264] (NN) : [0.42285529] (DT)
# Final prediction value: [117.72969472]
#
# NN Predictions: [218.91215994]
# LR Predictions: 220.1827203436436
# DT Predictions: [220.77252087]
# Actual: 221.46928361366915
# Error ratio is [0.30316341] (LR) : [0.27482957] (NN) : [0.42200702] (DT)
# Final prediction value: [220.08243274]
#
# NN Predictions: [148.18815895]
# LR Predictions: 147.88185524458225
# DT Predictions: [145.43638064]
# Actual: 149.07800220373113
# Error ratio is [0.30257866] (LR) : [0.27456849] (NN) : [0.42285286] (DT)
# Final prediction value: [146.93188067]
#
# NN Predictions: [227.623672]
# LR Predictions: 229.6839153662396
# DT Predictions: [237.82572365]
# Actual: 233.2918357915463
# Error ratio is [0.30359784] (LR) : [0.27444269] (NN) : [0.42195948] (DT)
# Final prediction value: [232.55400981]
#
# NN Predictions: [246.38903916]
# LR Predictions: 247.06151433500122
# DT Predictions: [246.01666341]
# Actual: 249.1953766416157
# Error ratio is [0.30383017] (LR) : [0.27437851] (NN) : [0.42179131] (DT)
# Final prediction value: [246.43629255]
#
# NN Predictions: [151.99679723]
# LR Predictions: 152.3886231115855
# DT Predictions: [152.89082298]
# Actual: 152.23685741248187
# Error ratio is [0.30377735] (LR) : [0.2742866] (NN) : [0.42193605] (DT)
# Final prediction value: [152.49304675]
#
# NN Predictions: [233.94085535]
# LR Predictions: 235.03409711113363
# DT Predictions: [231.69999695]
# Actual: 233.36392650842956
# Error ratio is [0.3033629] (LR) : [0.27469174] (NN) : [0.42194536] (DT)
# Final prediction value: [233.32698454]
#
# NN Predictions: [106.14034114]
# LR Predictions: 106.76907647767409
# DT Predictions: [106.66824506]
# Actual: 111.02601237155882
# Error ratio is [0.30389388] (LR) : [0.27506033] (NN) : [0.42104579] (DT)
# Final prediction value: [106.55368168]
#
# NN Predictions: [111.3729507]
# LR Predictions: 111.2437844592379
# DT Predictions: [109.30429842]
# Actual: 112.59145244287018
# Error ratio is [0.30351885] (LR) : [0.27488472] (NN) : [0.42159643] (DT)
# Final prediction value: [110.46160989]
#
# NN Predictions: [123.69544556]
# LR Predictions: 123.60595392927816
# DT Predictions: [124.94524675]
# Actual: 124.94526644040783
# Error ratio is [0.30382887] (LR) : [0.27530408] (NN) : [0.42086705] (DT)
# Final prediction value: [124.19425556]
#
# NN Predictions: [208.0739054]
# LR Predictions: 208.60688464755185
# DT Predictions: [208.56948084]
# Actual: 205.58677037884885
# Error ratio is [0.3037675] (LR) : [0.27575776] (NN) : [0.42047474] (DT)
# Final prediction value: [208.44418413]
#
# NN Predictions: [149.5528617]
# LR Predictions: 149.79336349933754
# DT Predictions: [147.4629339]
# Actual: 150.0005248051165
# Error ratio is [0.30342134] (LR) : [0.27531142] (NN) : [0.42126723] (DT)
# Final prediction value: [148.74541698]
#
# NN Predictions: [186.58209703]
# LR Predictions: 185.84278034329682
# DT Predictions: [190.40243381]
# Actual: 182.6734238450404
# Error ratio is [0.30303783] (LR) : [0.27471578] (NN) : [0.42224639] (DT)
# Final prediction value: [187.97117951]
#
# NN Predictions: [183.23976751]
# LR Predictions: 183.89286721857894
# DT Predictions: [181.71235185]
# Actual: 182.24128500065143
# Error ratio is [0.30306085] (LR) : [0.27522571] (NN) : [0.42171345] (DT)
# Final prediction value: [182.79356474]
#
# NN Predictions: [146.43816889]
# LR Predictions: 147.22990417883128
# DT Predictions: [145.6811557]
# Actual: 150.1030594439155
# ...
# Final prediction value: [187.95419082]
#
# NN Predictions: [199.93482183]
# LR Predictions: 199.49910944489503
# DT Predictions: [200.36260025]
# Actual: 200.05295557621693
# Error ratio is [0.29798464] (LR) : [0.27249256] (NN) : [0.4295228] (DT)
# Final prediction value: [199.98872682]
#
# NN Predictions: [138.54897847]
# LR Predictions: 138.5645424450264
# DT Predictions: [138.45729988]
# Actual: 139.12204872384297
# Error ratio is [0.29799881] (LR) : [0.27251796] (NN) : [0.42948323] (DT)
# Final prediction value: [138.5142421]
#
# NN Predictions: [109.68942553]
# LR Predictions: 109.60391965246184
# DT Predictions: [109.30429842]
# Actual: 108.03005218595369
# Error ratio is [0.29811621] (LR) : [0.27264627] (NN) : [0.42923752] (DT)
# Final prediction value: [109.49862383]
#
# NN Predictions: [152.32079408]
# LR Predictions: 154.04886717081894
# DT Predictions: [152.22067722]
# Actual: 155.6998128738619
# Error ratio is [0.29842803] (LR) : [0.2723986] (NN) : [0.42917337] (DT)
# Final prediction value: [152.79353204]
#
# NN Predictions: [134.70960696]
# LR Predictions: 135.1224849096835
# DT Predictions: [133.74011177]
# Actual: 142.93209356986327
# Error ratio is [0.2986829] (LR) : [0.27274285] (NN) : [0.42857425] (DT)
# Final prediction value: [134.41742587]
#
# NN Predictions: [141.65705113]
# LR Predictions: 141.13026815190557
# DT Predictions: [141.43587079]
# Actual: 140.90374795912805
# Error ratio is [0.2987935] (LR) : [0.27267472] (NN) : [0.42853178] (DT)
# Final prediction value: [141.40486899]
#
# NN Predictions: [229.02235532]
# LR Predictions: 230.00532490911715
# DT Predictions: [231.77720359]
# Actual: 227.59609977127653
# Error ratio is [0.29843932] (LR) : [0.27275634] (NN) : [0.42880434] (DT)
# Final prediction value: [230.49700299]
#
# NN Predictions: [123.37220408]
# LR Predictions: 123.76044290278104
# DT Predictions: [124.94524675]
# Actual: 122.74587286479516
# Error ratio is [0.29824962] (LR) : [0.27274433] (NN) : [0.42900604] (DT)
# Final prediction value: [124.16284097]
#
# NN Predictions: [166.23162886]
# LR Predictions: 166.0049318765845
# DT Predictions: [165.02495745]
# Actual: 168.94303442923228
# Error ratio is [0.29819793] (LR) : [0.27286385] (NN) : [0.42893822] (DT)
# Final prediction value: [165.6464408]
#
# NN Predictions: [187.09979637]
# LR Predictions: 187.98398907588438
# DT Predictions: [186.2729496]
# Actual: 190.68558968364889
# Error ratio is [0.29834106] (LR) : [0.27278485] (NN) : [0.42887409] (DT)
# Final prediction value: [187.0089742]
#
# NN Predictions: [241.69694394]
# LR Predictions: 242.95218752053768
# DT Predictions: [243.4457849]
# Actual: 242.12049100282684
# Error ratio is [0.2982157] (LR) : [0.27283109] (NN) : [0.4289532] (DT)
# Final prediction value: [242.82144822]
#
# NN Predictions: [169.48608872]
# LR Predictions: 170.41456525986302
# DT Predictions: [169.55919331]
# Actual: 171.40734829469508
# Error ratio is [0.29839677] (LR) : [0.27272035] (NN) : [0.42888288] (DT)
# Final prediction value: [169.79449643]
#
# NN Predictions: [133.46443672]
# LR Predictions: 133.1624565813205
# DT Predictions: [131.10574623]
# Actual: 142.06740859428484
# Error ratio is [0.2984353] (LR) : [0.27312833] (NN) : [0.42843637] (DT)
# Final prediction value: [132.36376641]
#
# NN Predictions: [222.87369898]
# LR Predictions: 223.5816167077433
# DT Predictions: [224.95305328]
# Actual: 223.21759527142092
# Error ratio is [0.29829762] (LR) : [0.27301994] (NN) : [0.42868244] (DT)
# Final prediction value: [223.97625183]
#
# NN Predictions: [205.54113158]
# LR Predictions: 206.049881352753
# DT Predictions: [202.6040848]
# Actual: 211.87752992550045
# Error ratio is [0.29827693] (LR) : [0.273011] (NN) : [0.42871208] (DT)
# Final prediction value: [204.43373247]
#
# NN Predictions: [117.95577636]
# LR Predictions: 118.77544917624138
# DT Predictions: [122.66459306]
# Actual: 120.6738663324064
# Error ratio is [0.29854132] (LR) : [0.27304445] (NN) : [0.42841422] (DT)
# Final prediction value: [120.21780662]
#
# NN Predictions: [132.2628909]
# LR Predictions: 132.58933205820455
# DT Predictions: [128.08060684]
# Actual: 132.81015030717464
# Error ratio is [0.29815501] (LR) : [0.27259237] (NN) : [0.42925261] (DT)
# Final prediction value: [130.56496461]
#
# NN Predictions: [146.57043774]
# LR Predictions: 147.4652969279544
# DT Predictions: [146.21957783]
# Actual: 147.00163818021238
# Error ratio is [0.29813074] (LR) : [0.27259468] (NN) : [0.42927458] (DT)
# Final prediction value: [146.68660753]
#
# NN Predictions: [113.38345043]
# LR Predictions: 113.88206124411553
# DT Predictions: [116.55723598]
# Actual: 113.97508586515107
# Error ratio is [0.29799598] (LR) : [0.27231357] (NN) : [0.42969045] (DT)
# Final prediction value: [114.89577979]
#
# NN Predictions: [149.47333398]
# LR Predictions: 150.88700728429635
# DT Predictions: [145.34566573]
# Actual: 154.8949324005984
# Error ratio is [0.29791404] (LR) : [0.2719073] (NN) : [0.43017866] (DT)
# Final prediction value: [148.11885233]
#
# NN Predictions: [211.48498438]
# LR Predictions: 212.07561016498357
# DT Predictions: [207.67431084]
# Actual: 216.3316233309755
# Error ratio is [0.29775943] (LR) : [0.27170788] (NN) : [0.43053268] (DT)
# Final prediction value: [210.02022927]
#
# NN Predictions: [233.50170553]
# LR Predictions: 234.37386174694086
# DT Predictions: [232.99563707]
# Actual: 234.96486230654432
# Error ratio is [0.29785157] (LR) : [0.27153337] (NN) : [0.43061505] (DT)
# Final prediction value: [233.54355793]
#
# NN Predictions: [168.64233874]
# LR Predictions: 168.6901605292849
# DT Predictions: [167.79503441]
# Actual: 169.68837067678015
# Error ratio is [0.29780758] (LR) : [0.27150874] (NN) : [0.43068368] (DT)
# Final prediction value: [168.29166029]
#
# NN Predictions: [230.92064484]
# LR Predictions: 232.08494591772745
# DT Predictions: [233.97938842]
# Actual: 235.0859033854084
# Error ratio is [0.29839638] (LR) : [0.27176995] (NN) : [0.42983367] (DT)
# Final prediction value: [232.58281906]
#
# NN Predictions: [161.25172049]
# LR Predictions: 161.59732013725446
# DT Predictions: [165.76652602]
# Actual: 165.3789138092183
# Error ratio is [0.29896625] (LR) : [0.27229679] (NN) : [0.42873696] (DT)
# Final prediction value: [163.29070713]
#
# NN Predictions: [175.46180335]
# LR Predictions: 175.60356204278153
# DT Predictions: [170.62871045]
# Actual: 175.42173612638558
# Error ratio is [0.29846362] (LR) : [0.27188906] (NN) : [0.42964732] (DT)
# Final prediction value: [173.42758775]
#
# NN Predictions: [142.22280592]
# LR Predictions: 142.16547245480038
# DT Predictions: [146.20407279]
# Actual: 146.06817770971523
# Error ratio is [0.29897625] (LR) : [0.27249335] (NN) : [0.4285304] (DT)
# Final prediction value: [143.91175847]
#
# NN Predictions: [251.5431529]
# LR Predictions: 253.54829470572065
# DT Predictions: [257.27667868]
# Actual: 254.58626151312842
# Error ratio is [0.29932534] (LR) : [0.2722167] (NN) : [0.42845796] (DT)
# Final prediction value: [254.59991742]
#
# NN Predictions: [187.76865343]
# LR Predictions: 188.23395148930206
# DT Predictions: [189.29735129]
# Actual: 189.78228064107432
# Error ratio is [0.29959992] (LR) : [0.27236958] (NN) : [0.4280305] (DT)
# Final prediction value: [188.562386]
#
# NN Predictions: [140.37679056]
# LR Predictions: 140.49982180372493
# DT Predictions: [135.13615452]
# Actual: 139.7576013848175
# Error ratio is [0.29919919] (LR) : [0.27206652] (NN) : [0.42873429] (DT)
# Final prediction value: [138.16676104]
#
# NN Predictions: [227.2996578]
# LR Predictions: 228.49707838378816
# DT Predictions: [227.72160927]
# Actual: 223.5198165983548
# Error ratio is [0.29916606] (LR) : [0.27256011] (NN) : [0.42827383] (DT)
# Final prediction value: [227.83859617]
#
# NN Predictions: [138.92563347]
# LR Predictions: 140.08927847393878
# DT Predictions: [138.3958089]
# Actual: 141.00166195751657
# Error ratio is [0.29930263] (LR) : [0.27235227] (NN) : [0.4283451] (DT)
# Final prediction value: [139.04696773]
#
# NN Predictions: [235.11035426]
# LR Predictions: 236.32977748552565
# DT Predictions: [223.26351529]
# Actual: 231.2989028272768
# Error ratio is [0.29888415] (LR) : [0.27249879] (NN) : [0.42861706] (DT)
# Final prediction value: [230.39706329]
#
# NN Predictions: [145.37631386]
# LR Predictions: 146.43720058124552
# DT Predictions: [145.41679587]
# Actual: 144.36741964547258
# Error ratio is [0.29880836] (LR) : [0.27281721] (NN) : [0.42837443] (DT)
# Final prediction value: [145.71065714]
#
# NN Predictions: [192.84047328]
# LR Predictions: 193.78761473969553
# DT Predictions: [192.6390709]
# Actual: 194.074422779809
# Error ratio is [0.2989264] (LR) : [0.27264226] (NN) : [0.42843134] (DT)
# Final prediction value: [193.03731178]
#
# NN Predictions: [168.63678516]
# LR Predictions: 169.56904359413502
# DT Predictions: [173.817477]
# Actual: 168.57908068618394
# Error ratio is [0.29831452] (LR) : [0.27239908] (NN) : [0.4292864] (DT)
# Final prediction value: [171.13889194]
#
# NN Predictions: [191.26740013]
# LR Predictions: 191.59580989954404
# DT Predictions: [185.57881485]
# Actual: 191.45904261144975
# Error ratio is [0.29775785] (LR) : [0.27187795] (NN) : [0.4303642] (DT)
# Final prediction value: [188.91702329]
#
# NN Predictions: [221.60389996]
# LR Predictions: 222.80832978339114
# DT Predictions: [217.66386764]
# Actual: 220.84940592957574
# Error ratio is [0.29742261] (LR) : [0.27199677] (NN) : [0.43058062] (DT)
# Final prediction value: [220.26562307]
#
# NN Predictions: [173.64452165]
# LR Predictions: 173.98352499878285
# DT Predictions: [174.34503855]
# Actual: 174.33240207355175
# Error ratio is [0.29754829] (LR) : [0.27201799] (NN) : [0.43043372] (DT)
# Final prediction value: [174.04691761]
#
# NN Predictions: [231.67197815]
# LR Predictions: 232.52642893928677
# DT Predictions: [231.53243989]
# Actual: 229.25
# Error ratio is [0.29756407] (LR) : [0.27238676] (NN) : [0.43004917] (DT)
# Final prediction value: [231.86622369]
#
# NN Predictions: [152.45720225]
# LR Predictions: 152.5305508423477
# DT Predictions: [153.05397081]
# Actual: 151.74096513145994
# Error ratio is [0.29752323] (LR) : [0.27239402] (NN) : [0.43008276] (DT)
# Final prediction value: [152.73568503]
#
# NN Predictions: [139.55887786]
# LR Predictions: 139.9585005113816
# DT Predictions: [135.13615452]
# Actual: 135.947746278508
# Error ratio is [0.29788944] (LR) : [0.27296347] (NN) : [0.42914708] (DT)
# Final prediction value: [137.7799224]
#
# NN Predictions: [145.01446354]
# LR Predictions: 145.81078170722574
# DT Predictions: [145.69094622]
# Actual: 145.22638831235219
# Error ratio is [0.29783507] (LR) : [0.27304327] (NN) : [0.42912166] (DT)
# Final prediction value: [145.54192839]
#
# NN Predictions: [221.18963295]
# LR Predictions: 221.3394321104925
# DT Predictions: [225.77666755]
# Actual: 227.9199981689453
# Error ratio is [0.29853821] (LR) : [0.27382352] (NN) : [0.42763826] (DT)
# Final prediction value: [223.19594524]
#
# NN Predictions: [158.50518226]
# LR Predictions: 158.68548104510126
# DT Predictions: [162.46257811]
# Actual: 157.39340627106276
# Error ratio is [0.29816923] (LR) : [0.27357488] (NN) : [0.42825589] (DT)
# Final prediction value: [160.2537199]
#
# NN Predictions: [164.27001075]
# LR Predictions: 164.86175627819708
# DT Predictions: [168.19793053]
# Actual: 164.31870136319566
# Error ratio is [0.29774641] (LR) : [0.27335099] (NN) : [0.42890259] (DT)
# Final prediction value: [166.13089584]
#
# NN Predictions: [186.72692147]
# LR Predictions: 187.2837611999324
# DT Predictions: [187.17143117]
# Actual: 187.07659264846137
# Error ratio is [0.29779763] (LR) : [0.27336055] (NN) : [0.42884182] (DT)
# Final prediction value: [187.08337137]
#
# NN Predictions: [230.88178171]
# LR Predictions: 231.46772770642795
# DT Predictions: [233.97938842]
# Actual: 228.27758291037028
# Error ratio is [0.29752899] (LR) : [0.27337614] (NN) : [0.42909487] (DT)
# Final prediction value: [232.38528478]
#
# NN Predictions: [212.10085418]
# LR Predictions: 212.61288042735052
# DT Predictions: [207.67431084]
# Actual: 209.86183643928914
# Error ratio is [0.29756284] (LR) : [0.27363419] (NN) : [0.42880297] (DT)
# Final prediction value: [210.35509922]
#
# NN Predictions: [163.50512091]
# LR Predictions: 164.89573354700585
# DT Predictions: [168.32127707]
# Actual: 167.41725259761515
# Error ratio is [0.29812697] (LR) : [0.27380182] (NN) : [0.42807121] (DT)
# Final prediction value: [165.98135786]
#
# NN Predictions: [121.27527857]
# LR Predictions: 121.9377720301754
# DT Predictions: [118.80998608]
# Actual: 123.41056406877745
# Error ratio is [0.29802545] (LR) : [0.27354967] (NN) : [0.42842488] (DT)
# Final prediction value: [120.41652583]
#
# NN Predictions: [167.20464029]
# LR Predictions: 167.56305815873304
# DT Predictions: [173.0175481]
# Actual: 162.84513031273676
# Error ratio is [0.29757994] (LR) : [0.27337247] (NN) : [0.42904759] (DT)
# Final prediction value: [169.80531233]
#
# NN Predictions: [199.68328512]
# LR Predictions: 199.21156261926293
# DT Predictions: [200.36260025]
# Actual: 199.50357538920457
# Error ratio is [0.29751002] (LR) : [0.27334927] (NN) : [0.42914072] (DT)
# Final prediction value: [199.83446473]
#
# NN Predictions: [112.38824978]
# LR Predictions: 112.50169500481778
# DT Predictions: [112.13491305]
# Actual: 116.78448204587328
# Error ratio is [0.29764871] (LR) : [0.2735551] (NN) : [0.42879619] (DT)
# Final prediction value: [112.31338678]
#
# NN Predictions: [212.17274591]
# LR Predictions: 212.92195879984416
# DT Predictions: [213.69691814]
# Actual: 214.75626907170553
# Error ratio is [0.29795502] (LR) : [0.27366307] (NN) : [0.42838191] (DT)
# Final prediction value: [213.04890546]
#
# NN Predictions: [228.66794472]
# LR Predictions: 229.20146269975905
# DT Predictions: [224.84356992]
# Actual: 227.4912604304481
# Error ratio is [0.2978035] (LR) : [0.27372581] (NN) : [0.42847069] (DT)
# Final prediction value: [227.18819573]
#
# NN Predictions: [221.32539754]
# LR Predictions: 220.72416428282955
# DT Predictions: [223.94503225]
# Actual: 220.60332780966414
# Error ratio is [0.2976356] (LR) : [0.27339759] (NN) : [0.4289668] (DT)
# Final prediction value: [222.27018545]
#
# NN Predictions: [168.32061531]
# LR Predictions: 168.8191168736108
# DT Predictions: [168.01956783]
# Actual: 169.19499314475576
# Error ratio is [0.29768439] (LR) : [0.27330563] (NN) : [0.42900998] (DT)
# Final prediction value: [168.33985907]
#
# NN Predictions: [154.97116957]
# LR Predictions: 154.30239121325886
# DT Predictions: [152.41407809]
# Actual: 155.2482493800242
# Error ratio is [0.29738688] (LR) : [0.27325353] (NN) : [0.42935959] (DT)
# Final prediction value: [153.67437192]
#
# NN Predictions: [188.88368324]
# LR Predictions: 189.33213199482512
# DT Predictions: [189.29773022]
# Actual: 188.3255839995523
# Error ratio is [0.29732418] (LR) : [0.27335362] (NN) : [0.4293222] (DT)
# Final prediction value: [189.19477746]
#
# NN Predictions: [170.34813582]
# LR Predictions: 170.76886088907375
# DT Predictions: [171.32542256]
# Actual: 170.90392591816433
# Error ratio is [0.29739604] (LR) : [0.27329966] (NN) : [0.4293043] (DT)
# Final prediction value: [170.89281119]
#
# NN Predictions: [145.54264939]
# LR Predictions: 145.932397665901
# DT Predictions: [147.22793196]
# Actual: 146.54264911827497
# Error ratio is [0.29749728] (LR) : [0.2732942] (NN) : [0.42920851] (DT)
# Final prediction value: [146.38193607]
#
# NN Predictions: [243.89955949]
# LR Predictions: 245.6676932107139
# DT Predictions: [229.17645245]
# Actual: 247.0828737526952
# Error ratio is [0.29638476] (LR) : [0.2717941] (NN) : [0.43182114] (DT)
# Final prediction value: [238.06585846]
#
# NN Predictions: [226.34502088]
# LR Predictions: 227.44057826531315
# DT Predictions: [228.97432934]
# Actual: 230.47183871784506
# Error ratio is [0.29687806] (LR) : [0.27200852] (NN) : [0.43111342] (DT)
# Final prediction value: [227.80379799]
#
# NN Predictions: [154.15281278]
# LR Predictions: 155.1477451418115
# DT Predictions: [158.51411543]
# Actual: 150.01198791697018
# Error ratio is [0.29652077] (LR) : [0.27210271] (NN) : [0.43137653] (DT)
# Final prediction value: [156.32919447]
#
# NN Predictions: [180.23324201]
# LR Predictions: 181.14396919056193
# DT Predictions: [183.83067067]
# Actual: 179.97756989489093
# Error ratio is [0.29611036] (LR) : [0.27201834] (NN) : [0.4318713] (DT)
# Final prediction value: [182.05654395]
#
# NN Predictions: [223.93226258]
# LR Predictions: 224.25826352136286
# DT Predictions: [227.97390378]
# Actual: 223.22755241503756
# Error ratio is [0.29573018] (LR) : [0.27178908] (NN) : [0.43248074] (DT)
# Final prediction value: [225.77660288]
#
# Final Average Error is:  [1.4205092] %
# MSE value of Three Models Combination Model is:  10.981394614820745

# %%
actual_val = y_test[0]
pred_list = [LR_y_pred, NN_y_pred, DT_y_pred, three_list]
pred_list = [np.array(p).flatten() for p in pred_list]
pred_ind = []
mod_list = ["LR Prediction:", "NN Prediction:", "DT Prediction:", "Three Model Prediction:"]
prox_list = [(actual_val - LR_y_pred[0]), (actual_val - NN_y_pred[0]), (actual_val - DT_y_pred[0]), (actual_val - three_list[0])]
acc_pred_list = []

#Change the proximity value to absolute.
for i in range(len(prox_list)):
  prox_list[i] = abs(prox_list[i])

#Determine the two indexes with predicted values closest to the actual value
for i in range(0, 2):
  pred_ind.append(prox_list.index(min(prox_list)))
  prox_list[pred_ind[i]] = 10000000000

#print the two indexes
for i in range(0, 2):
  print(pred_ind[i])

#Final MSE Error

closest_combined_pred = (pred_list[pred_ind[0]]+pred_list[pred_ind[1]])/2
closest_combined_MSE = mean_squared_error(y_test, closest_combined_pred)
print("Mean squared error: %.2f" % closest_combined_MSE)
# Out:
# 3
# 0
# Mean squared error: 9.12

# %% [markdown]
# Tesla: Predictions (Monday = 259.3434673376589(NN), 259.43269652(LR)), (Tuesday = 260.25472715866357(NN), 258.25222344(LR)), (Wednesday = 252.9906057716744(NN), 251.28043536(LR)), (Thursday = 242.42908011253357(NN), 243.28207527(LR)), (Friday = 254.10978717038498(NN), 256.81248751(LR)), term = Last 3 days
#
# Tesla: Predictions (Monday = 255.39245155305224(NN), 257.36577365(LR)), (Tuesday = 252.89518350193396(NN), 258.9103237(LR)), (Wednesday = 254.89930696941917(NN), 248.47467418(LR)), (Thursday = 247.05356603194483(NN), 242.40142806(LR)), (Friday = 251.22187228479018(NN), 257.61861851(LR)), term = Last 5 days
#
# Real Tesla Stock Prices (Monday = 250.02, Tuesday = 243.15, Wednesday = 243.2, Thrusday = 257.84, Friday = 260.63)
#
#
# Apple: Predictions (Monday = 185.04601053842558(NN), 185.36794501(LR)), (Tuesday = 186.28321343151617(NN), 185.56492498(LR)), (Wednesday = 186.3198122856117(NN), 186.78643675(LR)), (Thursday = 185.7340687632026(NN), 186.11884907(LR)), (Friday = 188.3205993811893(NN), 189.08076126(LR)), term = Last 3 days
#
# Apple: Predictions (Monday = 184.32129621738207(NN), 185.78559101(LR)), (Tuesday = 184.6519646982332(NN), 185.51485266(LR)), (Wednesday = 186.76168906258465(NN), 186.72036983(LR)), (Thursday = 184.82757539191303(NN), 185.75783144(LR)), (Friday = 188.14432386071064(NN), 189.07363645(LR)), term = Last 5 days
#
# Real Apple Stock Prices (Monday = 185.48, Tuesday = 186.82, Wednesday = 185.9, Thrusday = 189.21, Friday = 191.78)
#
#
# Papa Johns: Predictions (Monday = 72.13058243971048(NN), 72.62154468(LR)), (Tuesday = 72.68137640403584(NN), 72.70792263(LR)), (Wednesday = 70.76979012537055(NN), 70.49938953(LR)), (Thursday = 72.33165301475981(NN), 72.32238143(LR)), (Friday = 72.955632395817(NN), 72.83569683(LR)), term = Last 3 days.
#
# Papa Johns: Predictions (Monday = 72.30619112884433(NN), 72.70647876(LR)), (Tuesday = 73.1015127499096(NN), 72.81604794(LR)), (Wednesday = 70.4073474478508(NN), 70.40201571(LR)), (Thursday = 72.0603075489961(NN), 72.31713888(LR)), (Friday = 72.35666122743858(NN), 72.85776773(LR)), term = Last 5 days
#
# Real Papa Johns Stock Prices (Monday = 72.75, Tuesday = 70.4, Wednesday = 72.38, Thrusday = 72.83, Friday = 73.84)

# %%
import matplotlib.pyplot as plt
NN_x_values = range(1, len(y_test) + 1)

plt.scatter(NN_x_values[:10], y_test[:10], c='blue', label='Real Stock Prices')
plt.scatter(NN_x_values[:10], NN_y_pred[:10], c='red', label='Predicted Stock price by Neural Network')
plt.xlabel('Real Stock Prices')
plt.ylabel('Predicted Stock Price by Neural Network')
plt.show()

# %%
import matplotlib.pyplot as plt
LR_x_values = range(1, len(y_test) + 1)

plt.scatter(LR_x_values[:10], y_test[:10], c='blue', label='Real Stock Prices')
plt.scatter(LR_x_values[:10], LR_y_pred[:10], c='red', label='Predicted Stock price by Linear Regresison')
plt.xlabel('Real Stock Prices')
plt.ylabel('Predicted Stock Price by Linear Regresison')
plt.show()

# %%
import matplotlib.pyplot as plt
DT_x_values = range(1, len(y_test) + 1)

plt.scatter(DT_x_values[:10], y_test[:10], c='blue', label='Real Stock Prices')
plt.scatter(DT_x_values[:10], LR_y_pred[:10], c='red', label='Predicted Stock price by Decision Tree Regressor')
plt.xlabel('Real Stock Prices')
plt.ylabel('Predicted Stock Price by Decision Tree Regressor')
plt.show()

# %%
https://epfl.zoom.us/j/5759729771?pwd=ZDBUVWk0UDhkaFlXbHM0SGxaMEVIZz09

# %% [markdown]
# # Task
# Explain the error in the selected code, fix it, and incorporate the changes into the existing code.

# %% [markdown]
# ## Inspect data types
#
# ### Subtask:
# Check the data type of `data` before the loop.

# %% [markdown]
# **Reasoning**:
# Print the type of the variable `data` to understand its structure and identify the cause of the ValueError.

# %%
print(type(data))

# %% [markdown]
# **Reasoning**:
# The variable `data` is a numpy array. The error indicates setting an array element with a sequence, which suggests that the structure of `data` is not as expected when trying to assign to `X[i, :]`. Let's examine the shape of `data` to further understand the issue.

# %%
print(data.shape)

# %% [markdown]
# **Reasoning**:
# The variable `data` is a numpy array with shape (1256, 1), which means it's a 2D array with 1256 rows and 1 column. When trying to assign `[data[1 + i], data[2 + i], data[3 + i]]` to `X[i, :]`, the error "setting an array element with a sequence" occurs because `X[i, :]` is a slice of a 2D array (a 1D array), while `[data[1 + i], data[2 + i], data[3 + i]]` is a sequence of 1D arrays (each `data[j]` is `[value]`). To fix this, we need to extract the scalar value from each element of `data`.

# %%
#Linear Regression Model

import yfinance as yf
import pandas as pd
import numpy as np


ticker = yf.Ticker('AAPL') #import data, loaded 5 years of past data of AAPL (Matrix form)
aapl_df = ticker.history(period="5y") #get data from 5 year period in dataframe
aapl_df.drop(['High','Low','Close','Volume'], axis=1, inplace=True) #only have two columns, not seven
data = aapl_df[['Open']].to_numpy() # Use to_numpy() directly

X = np.zeros((len(data)-4,3)) #Matrix of 1250 rows and 4 columns
Y = [0]*(len(data)-4)

for i in range(len(data)-4):
  X[i, :] = [data[1 + i][0], data[2 + i][0], data[3 + i][0]] #filling up matrix by accessing the scalar value with [0]
  Y[i] = data[4 + i][0] # Also access the scalar value for Y

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

# Create linear regression object
LR_regr = linear_model.LinearRegression()

# Train the model using the training sets
LR_regr.fit(X_train, y_train)

# Make predictions using the testing set
LR_y_pred = LR_regr.predict(X_test)

# The coefficients
print("Coefficients: \n", LR_regr.coef_)
# The mean squared error
LR_MSE = mean_squared_error(y_test, LR_y_pred)
print("Mean squared error: %.2f" % LR_MSE)
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, LR_y_pred))

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The variable `data`, which holds the 'Open' stock prices, is a 2D NumPy array with a shape of (1256, 1).
# *   The original code produced a `ValueError` because it was attempting to assign a sequence (a single-element array like `[value]`) from the `data` array to an element of the `X` matrix, which expected a scalar value.
#
# ### Insights or Next Steps
#
# *   When working with NumPy arrays resulting from selecting a single column from a pandas DataFrame and using `.to_numpy()`, be mindful that they retain a 2D shape. Accessing individual values requires indexing into the single column (e.g., `data[i][0]`).
